# %% [markdown]
# This is a simple Julia 0.6 notebook. Below we'll show off the Julia `PyPlot` module.

# %%
using PyPlot
ioff() # Interactive plotting OFF, necessary for inline plotting in IJulia

# %%
x = 100 * rand(500)
y = 100 * rand(500)
areas = 800 * rand(500);

# %%
#  Scatterplot
fig = figure("scatterplot",figsize=(10,10))
# ax = axes()
scatter(x,y,s=areas,alpha=0.5, c=areas)

title("Scatter Plot")
xlabel("X")
ylabel("Y")
grid("on")
gcf();
# Out:
# Figure(PyObject <Figure size 1000x1000 with 1 Axes>)
# C:\Users\bkjhu\.julia\packages\Conda\hsaaN\deps\usr\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
# Datatype: fundamental

# %%
x = true
# Out:
# true

# %%
typeof(x)
# Out:
# Bool

# %%
y = 1 > 2
# Out:
# false

# %%
true + false
# Out:
# 1

# %%
sum([true, false, false, true])
# Out:
# 2

# %%
typeof(1.0)
# Out:
# Float64

# %%
typeof(1)
# Out:
# Int64

# %%
x = 2; y = 1.0
# Out:
# 1.0

# %%
x * y
# Out:
# 2.0

# %%
x^2
# Out:
# 4

# %%
y / x
# Out:
# 0.5

# %%
2/3
# Out:
# 0.6666666666666666

# %%
2x - 3y
# Out:
# 1.0

# %%
+(10, 20)
# Out:
# 30

# %%
*(10, 20)
# Out:
# 200

# %%
x = 1 + 2im
# Out:
# 1 + 2im

# %%
y = 1 - 2im
# Out:
# 1 - 2im

# %%
x * y
# Out:
# 5 + 0im

# %%
# Strings

# %%
x = "foobar"
# Out:
# "foobar"

# %%
typeof(x)
# Out:
# String

# %%
"x = $x"
# Out:
# "x = foobar"

# %%
x = 10; y = 20
# Out:
# 20

# %%
"x = $x"
# Out:
# "x = 10"

# %%
"x + y = $(x + y)"
# Out:
# "x + y = 30"

# %%
v = 1:10
"$v"
# Out:
# "1:10"

# %%
v[1]
# Out:
# 1

# %%
"foo" + "bar"
# Out:
# MethodError: no method matching +(::String, ::String)
# Closest candidates are:
#   +(::Any, ::Any, !Matched::Any, !Matched::Any...) at operators.jl:502
#   +(!Matched::PyCall.PyObject, ::Any) at C:\Users\bkjhu\.julia\packages\PyCall\rUul9\src\pyoperators.jl:14
#   +(::Any, !Matched::PyCall.PyObject) at C:\Users\bkjhu\.julia\packages\PyCall\rUul9\src\pyoperators.jl:15
#
# Stacktrace:
#  [1] top-level scope at In[29]:1

# %%
"foo" * "bar"
# Out:
# "foobar"

# %%
s = "CBS doesn't surf"
# Out:
# "CBS doesn't surf"

# %%
split(s)
# Out:
# 3-element Array{SubString{String},1}:
#  "CBS"
#  "doesn't"
#  "surf"

# %%
replace(s, "surf", "climbing")
# Out:
# MethodError: no method matching replace(::String, ::String, ::String)
# Closest candidates are:
#   replace(::String, !Matched::Pair{#s55,B} where B where #s55<:AbstractChar; count) at strings/util.jl:414
#   replace(::String, !Matched::Pair{#s52,B} where B where #s52<:Union{Tuple{Vararg{AbstractChar,N} where N}, Set{#s49} where #s49<:AbstractChar, AbstractArray{#s50,1} where #s50<:AbstractChar}; count) at strings/util.jl:419
#   replace(::String, !Matched::Pair; count) at strings/util.jl:423
#   ...
#
# Stacktrace:
#  [1] top-level scope at In[14]:1

# %%
split("fee,fi,fo", ",")
# Out:
# 3-element Array{SubString{String},1}:
#  "fee"
#  "fi"
#  "fo"

# %%
strip(" foobar ")  # Remove whitespace
# Out:
# "foobar"

# %%
match(r"(\d+)", "Top 10")  # Find digits in string
# Out:
# RegexMatch("10", 1="10")

# %%
# Tuple

# %%
x = ("foo", "bar")
# Out:
# ("foo", "bar")

# %%
typeof(x)
# Out:
# Tuple{String,String}

# %%
x[1]
# Out:
# "foo"

# %%
x[1] = 42
# Out:
# MethodError: no method matching setindex!(::Tuple{String,String}, ::Int64, ::Int64)
#
# Stacktrace:
#  [1] top-level scope at In[22]:1

# %%
x = "foo", "bar" # as in Python
# Out:
# ("foo", "bar")

# %%
x = ("foo", "bar")
# Out:
# ("foo", "bar")

# %%
word1, word2 = x
# Out:
# ("foo", "bar")

# %%
word1
# Out:
# "foo"

# %%
word2
# Out:
# "bar"

# %%
# indexing

# %%
x = [10, 20, 30, 40]
# Out:
# 4-element Array{Int64,1}:
#  10
#  20
#  30
#  40

# %%
x[end]
# Out:
# 40

# %%
x[end-1]
# Out:
# 30

# %%
x[1:3]
# Out:
# 3-element Array{Int64,1}:
#  10
#  20
#  30

# %%
x[2:end]
# Out:
# 3-element Array{Int64,1}:
#  20
#  30
#  40

# %%
"foobar"[3:end]
# Out:
# "obar"

# %%
d = Dict("name" => "Frodo", "age" => 33) # keys => values
# Out:
# Dict{String,Any} with 2 entries:
#   "name" => "Frodo"
#   "age"  => 33

# %%
d["age"]
# Out:
# 33

# %%
# interation

# %%
actions = ["surf", "climbing"]
for action in actions
    println("CBS doesn't $action")
end
# Out:
# CBS doesn't surf
# CBS doesn't climbing

# %%
?print
# Out:
# search: print println printstyled sprint isprint spring prevind parentindices
#   print([io::IO], xs...)
#
#   Write to io (or to the default output stream stdout if io is not given) a
#   canonical (un-decorated) text representation of values xs if there is one,
#   otherwise call show. The representation used by print includes minimal
#   formatting and tries to avoid Julia-specific details.
#
#   Printing nothing is deprecated and will throw an error in the future.
#
#   Examples
#   ≡≡≡≡≡≡≡≡≡≡
#
#   julia> print("Hello World!")
#   Hello World!
#   julia> io = IOBuffer();
#
#   julia> print(io, "Hello", ' ', :World!)
#
#   julia> String(take!(io))
#   "Hello World!"

# %%
for i in 1:3 print(i) end
# Out:
# 123

# %%
d = Dict("name" => "Frodo", "age" => 33)
# Out:
# Dict{String,Any} with 2 entries:
#   "name" => "Frodo"
#   "age"  => 33

# %%
typeof(keys(d))
# Out:
# Base.KeySet{String,Dict{String,Any}}

# %%
collect(keys(d))
# Out:
# 2-element Array{String,1}:
#  "name"
#  "age"

# %%
x_values = linspace(0, 3, 10)
# Out:
# UndefVarError: linspace not defined
#
# Stacktrace:
#  [1] top-level scope at In[62]:1

# %%
?linspace
# Out:
# search:
#
# Couldn't find linspace
# Perhaps you meant isspace or imsave
#   No documentation found.
#
#   Binding linspace does not exist.

# %%
for x in x_values
    println(x * x)
end
# Out:
# UndefVarError: x_values not defined
#
# Stacktrace:
#  [1] top-level scope at .\In[64]:1

# %%
for i in 1:length(x_values)
    println(x_values[i] * x_values[i])
end
# Out:
# UndefVarError: x_values not defined
#
# Stacktrace:
#  [1] top-level scope at .\In[65]:1

# %%
doubles = [2i for i in 1:4]
# Out:
# 4-element Array{Int64,1}:
#  2
#  4
#  6
#  8

# %%
doubles = [2*i for i in 1:4]
# Out:
# 4-element Array{Int64,1}:
#  2
#  4
#  6
#  8

# %%
animals = ["dog", "cat", "bird"];

# %%
animals = ["dog", "cat", "bird"]
# Out:
# 3-element Array{String,1}:
#  "dog"
#  "cat"
#  "bird"

# %%
plurals = [animal * "s" for animal in animals]
# Out:
# 3-element Array{String,1}:
#  "dogs"
#  "cats"
#  "birds"

# %%
[i + j for i in 1:3, j in 4:6]
# Out:
# 3×3 Array{Int64,2}:
#  5  6  7
#  6  7  8
#  7  8  9

# %%
[i + j + k for i in 1:3, j in 4:6, k in 7:9]
# Out:
# 3×3×3 Array{Int64,3}:
# [:, :, 1] =
#  12  13  14
#  13  14  15
#  14  15  16
#
# [:, :, 2] =
#  13  14  15
#  14  15  16
#  15  16  17
#
# [:, :, 3] =
#  14  15  16
#  15  16  17
#  16  17  18

# %%
Dict("$i" => i for i in 1:3)
# Out:
# Dict{String,Int64} with 3 entries:
#   "1" => 1
#   "2" => 2
#   "3" => 3

# %%
\delta + [Tab]

# %%
δ
